# %% [markdown]
# # Task

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'/Users/marianino/Desktop/Instacart Basket Analysis/Data/Prepared Data/orders_products_merged_derived.pkl')

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_last_order  add_to_cart_order  reordered _merge  \
# 0                    3.0                  5          0   both
# 1                   20.0                  1          1   both
# 2                    6.0                 20          0   both
# 3                    NaN                 10          0   both
# 4                    9.0                 11          1   both
#
#      price_range_loc     busiest_day    Busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly busy           Most orders
# 1  Mid-range product  Regularly busy  Regularly busy        Average orders
# 2  Mid-range product     Busiest day    Busiest days        Average orders
# 3  Mid-range product  Regularly busy    Slowest days           Most orders
# 4  Mid-range product      Least busy    Slowest days        Average orders

# %%
# Aggregated mean for the entire dataframe 
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# Comparing with the subset that I did during the lesson, the mean tends to be lower when using the entire data set.

# %% [markdown]
# # Loyalty Flags

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/zq/gd226qtd2tq509tvr0_wm2kc0000gn/T/ipykernel_9645/1681540670.py:1: FutureWarning: The provided callable <function amax at 0x10602d4e0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# /var/folders/zq/gd226qtd2tq509tvr0_wm2kc0000gn/T/ipykernel_9645/3647449420.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Checking loyalty flag
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Checking basic statistics of the products prices

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# # Spending Flag

# %%
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/zq/gd226qtd2tq509tvr0_wm2kc0000gn/T/ipykernel_9645/1521181374.py:1: FutureWarning: The provided callable <function mean at 0x10602e200> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...  add_to_cart_order  reordered  _merge    price_range_loc  \
# 0  ...                  5          0    both  Mid-range product
# 1  ...                  1          1    both  Mid-range product
# 2  ...                 20          0    both  Mid-range product
# 3  ...                 10          0    both  Mid-range product
# 4  ...                 11          1    both  Mid-range product
#
#       busiest_day    Busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy           Most orders        32
# 1  Regularly busy  Regularly busy        Average orders        32
# 2     Busiest day    Busiest days        Average orders         5
# 3  Regularly busy    Slowest days           Most orders         3
# 4      Least busy    Slowest days        Average orders         3
#
#        loyalty_flag average_price
# 0  Regular customer      6.935811
# 1  Regular customer      6.935811
# 2      New customer      7.930208
# 3      New customer      4.972414
# 4      New customer      4.972414
#
# [5 rows x 21 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'
# Out:
# /var/folders/zq/gd226qtd2tq509tvr0_wm2kc0000gn/T/ipykernel_9645/3814550370.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...  reordered  _merge    price_range_loc     busiest_day    Busiest_days  \
# 0  ...          0    both  Mid-range product  Regularly busy  Regularly busy
# 1  ...          1    both  Mid-range product  Regularly busy  Regularly busy
# 2  ...          0    both  Mid-range product     Busiest day    Busiest days
# 3  ...          0    both  Mid-range product  Regularly busy    Slowest days
# 4  ...          1    both  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day max_order      loyalty_flag  average_price  \
# 0           Most orders        32  Regular customer       6.935811
# 1        Average orders        32  Regular customer       6.935811
# 2        Average orders         5      New customer       7.930208
# 3           Most orders         3      New customer       4.972414
# 4        Average orders         3      New customer       4.972414
#
#   spending_flag
# 0   Low spender
# 1   Low spender
# 2   Low spender
# 3   Low spender
# 4   Low spender
#
# [5 rows x 22 columns]

# %% [markdown]
# # Frequency Flag

# %%
ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.mean)
# Out:
# /var/folders/zq/gd226qtd2tq509tvr0_wm2kc0000gn/T/ipykernel_9645/922803367.py:1: FutureWarning: The provided callable <function mean at 0x10602e200> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.mean)

# %%
ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
# Out:
# /var/folders/zq/gd226qtd2tq509tvr0_wm2kc0000gn/T/ipykernel_9645/2105341910.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_orders'] > 10) & (ords_prods_merge['median_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        16468582
# Regular customer         12521159
# Non-frequent customer     3415113
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...    price_range_loc     busiest_day    Busiest_days  \
# 0  ...  Mid-range product  Regularly busy  Regularly busy
# 1  ...  Mid-range product  Regularly busy  Regularly busy
# 2  ...  Mid-range product     Busiest day    Busiest days
# 3  ...  Mid-range product  Regularly busy    Slowest days
# 4  ...  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day max_order      loyalty_flag average_price  \
# 0           Most orders        32  Regular customer      6.935811
# 1        Average orders        32  Regular customer      6.935811
# 2        Average orders         5      New customer      7.930208
# 3           Most orders         3      New customer      4.972414
# 4        Average orders         3      New customer      4.972414
#
#   spending_flag  median_orders order_frequency_flag
# 0   Low spender      10.400000     Regular customer
# 1   Low spender      10.400000     Regular customer
# 2   Low spender       7.070968    Frequent customer
# 3   Low spender      10.948718     Regular customer
# 4   Low spender      10.948718     Regular customer
#
# [5 rows x 24 columns]

# %% [markdown]
# # Export Data

# %%
ords_prods_merge.to_pickle(r'/Users/marianino/Desktop/Instacart Basket Analysis/Data/Prepared Data/orders_products_merged_derived_aggregated.pkl')
